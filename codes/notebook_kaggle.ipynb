# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ROOT_PATH = '../data/dataset_chapmanShaoxing'

# %%
path = ROOT_PATH+ '/*.hea'

# %%
data_list =[]

for filepath in glob.glob(path, recursive=True):
    #print(filepath)
    with open(os.path.join(filepath), 'r') as f:
        lines = f.readlines()
        
        # Subject Id
        filename = lines[0].split()[0]

        # Total lead Number
        leads = lines[0].split()[1]

        # Sampling Frequency
        samp_freq = lines[0].split()[2]

        # Total Samples
        samples = lines[0].split()[3]

        # Lead I data
        first_value_I = lines[1].split()[5]
        last_value_I = lines[1].split()[6]
        lead_I = lines[1].split()[7]

        # Lead II data
        first_value_II = lines[2].split()[5]
        last_value_II = lines[2].split()[6]
        lead_II = lines[2].split()[7]


        # Lead III data
        first_value_III = lines[3].split()[5]
        last_value_III = lines[3].split()[6]
        lead_III = lines[3].split()[7]


        # Lead aVR data
        first_value_aVR = lines[4].split()[5]
        last_value_aVR = lines[4].split()[6]
        lead_aVR = lines[4].split()[7]


        # Lead aVL data
        first_value_aVL = lines[5].split()[5]
        last_value_aVL = lines[5].split()[6]
        lead_aVL = lines[5].split()[7]



        # Lead aVF data
        first_value_aVF = lines[6].split()[5]
        last_value_aVF = lines[6].split()[6]
        lead_aVF = lines[6].split()[7]


        # Lead V1 data
        first_value_v1= lines[7].split()[5]
        last_value_v1 = lines[7].split()[6]
        lead_V1 = lines[7].split()[7]

        # Lead V2 data
        first_value_v2 = lines[8].split()[5]
        last_value_v2 = lines[8].split()[6]
        lead_V2 = lines[8].split()[7]


        # Lead V3 data
        first_value_v3 = lines[9].split()[5]
        last_value_v3 = lines[9].split()[6]
        lead_V3 = lines[9].split()[7]

        # Lead V4 data
        first_value_v4 = lines[10].split()[5]
        last_value_v4 = lines[10].split()[6]
        lead_V4 = lines[10].split()[7]


        # Lead V5 data
        first_value_v5 = lines[11].split()[5]
        last_value_v5 = lines[11].split()[6]
        lead_V5 = lines[11].split()[7]


        # Lead V6 data
        first_value_v6 = lines[12].split()[5]
        last_value_v6 = lines[12].split()[6]
        lead_V6 = lines[12].split()[7]



        # Age
        age = lines[13].split()[1]

        # Sex
        sex = lines[14].split()[1]

        # Diagnosis
        dx = lines[15].split()[1]
        
        
        #print(filename, age, sex, dx, rx, hx)

        header_df = pd.DataFrame({
            
            "path":[os.path.splitext(filepath)[0]],
            "filename":[filename],
            "age":[age],
            "sex":[sex],
            "diagnosis":[dx],
            "leads":[leads],
            "frequency": [samp_freq],
            "samples":[samples],
            "lead_I_first": [first_value_I],
            "lead_I_last":[last_value_I],
            "lead_II_first": [first_value_II],
            "lead_II_last":[last_value_II],
            "lead_III_first": [first_value_III],
            "lead_III_last":[last_value_III],
            "lead_aVF_first": [first_value_aVF],
            "lead_aVF_last":[last_value_aVF],
            "lead_aVL_first": [first_value_aVL],
            "lead_aVL_last":[last_value_aVL],
            "lead_aVR_first": [first_value_aVR],
            "lead_aVR_last":[last_value_aVR],
            "lead_V1_first": [first_value_v1],
            "lead_V1_last":[last_value_v1],
            "lead_V2_first": [first_value_v2],
            "lead_V2_last":[last_value_v2],
            "lead_V3_first": [first_value_v3],
            "lead_V3_last":[last_value_v3],
            "lead_V4_first": [first_value_v4],
            "lead_V4_last":[last_value_v4],
            "lead_V5_first": [first_value_v5],
            "lead_V5_last":[last_value_v5],
            "lead_V6_first": [first_value_v6],
            "lead_V6_last":[last_value_v6],


        
        })
        data_list.append(header_df)

# %%
df = pd.concat(data_list).sort_values(by='path')

df.drop_duplicates(inplace=True)

df.to_csv(  '../data/dados_agrupados.csv', index=False)

# %%
data = pd.read_csv('../data/dados_agrupados.csv')
data.shape
# Out:
# (10247, 32)

# %%
data.head()
# Out:
#                                       path filename  age     sex  \
# 0  ../data/dataset_chapmanShaoxing\JS00001  JS00001   85    Male
# 1  ../data/dataset_chapmanShaoxing\JS00002  JS00002   59  Female
# 2  ../data/dataset_chapmanShaoxing\JS00004  JS00004   66    Male
# 3  ../data/dataset_chapmanShaoxing\JS00005  JS00005   73  Female
# 4  ../data/dataset_chapmanShaoxing\JS00006  JS00006   46  Female
#
#                        diagnosis  leads  frequency  samples  lead_I_first  \
# 0   164889003,59118001,164934002     12        500     5000          -254
# 1            426177001,164934002     12        500     5000           -10
# 2                      426177001     12        500     5000           195
# 3  164890007,429622005,428750005     12        500     5000             5
# 4                      426177001     12        500     5000           -29
#
#    lead_I_last  ...  lead_V2_first  lead_V2_last  lead_V3_first  lead_V3_last  \
# 0        21756  ...           -312        -32761            -98         32715
# 1        12346  ...            -54         16468             63        -29512
# 2       -22301  ...             88         12816             68         -3697
# 3        12980  ...           -386          3785           -381         -1927
# 4        25846  ...            -68        -15784            -78        -17397
#
#    lead_V4_first  lead_V4_last  lead_V5_first  lead_V5_last  lead_V6_first  \
# 0            810         15193            810         14081            527
# 1             54         -7548             49        -22267              0
# 2            293          -188            273        -12702            342
# 3           -356         27104           -220         -7044           -176
# 4            -49          -635            -88         -7549            -98
#
#    lead_V6_last
# 0         32579
# 1         31542
# 2         24967
# 3         -8125
# 4        -11358
#
# [5 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10247 entries, 0 to 10246
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   path            10247 non-null  object
#  1   filename        10247 non-null  object
#  2   age             10247 non-null  int64
#  3   sex             10247 non-null  object
#  4   diagnosis       10247 non-null  object
#  5   leads           10247 non-null  int64
#  6   frequency       10247 non-null  int64
#  7   samples         10247 non-null  int64
#  8   lead_I_first    10247 non-null  int64
#  9   lead_I_last     10247 non-null  int64
#  10  lead_II_first   10247 non-null  int64
#  11  lead_II_last    10247 non-null  int64
#  12  lead_III_first  10247 non-null  int64
#  13  lead_III_last   10247 non-null  int64
#  14  lead_aVF_first  10247 non-null  int64
#  15  lead_aVF_last   10247 non-null  int64
#  16  lead_aVL_first  10247 non-null  int64
#  17  lead_aVL_last   10247 non-null  int64
#  18  lead_aVR_first  10247 non-null  int64
#  19  lead_aVR_last   10247 non-null  int64
#  20  lead_V1_first   10247 non-null  int64
#  21  lead_V1_last    10247 non-null  int64
#  22  lead_V2_first   10247 non-null  int64
#  23  lead_V2_last    10247 non-null  int64
#  24  lead_V3_first   10247 non-null  int64
#  25  lead_V3_last    10247 non-null  int64
#  26  lead_V4_first   10247 non-null  int64
#  27  lead_V4_last    10247 non-null  int64
#  28  lead_V5_first   10247 non-null  int64
#  29  lead_V5_last    10247 non-null  int64
#  30  lead_V6_first   10247 non-null  int64
#  31  lead_V6_last    10247 non-null  int64
# dtypes: int64(28), object(4)
# memory usage: 2.5+ MB

# %%
data['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
sex = data['sex'].value_counts()

sorted_auth = sex.sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.countplot(x='sex', data=data, order=sorted_auth.index)

plt.xlabel("SEX")
plt.ylabel("Count")
plt.show()

# %%
sns.heatmap(data.corr(),  cmap="coolwarm", linecolor="black")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.heatmap(data.corr(),  cmap="coolwarm", linecolor="black")
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: '../data/dataset_chapmanShaoxing\\JS00001'

# %%
diag = data['diagnosis'].str.split(',', expand=True)
diag
# Out:
#                0          1          2     3     4     5     6     7     8  \
# 0      164889003   59118001  164934002  None  None  None  None  None  None
# 1      426177001  164934002       None  None  None  None  None  None  None
# 2      426177001       None       None  None  None  None  None  None  None
# 3      164890007  429622005  428750005  None  None  None  None  None  None
# 4      426177001       None       None  None  None  None  None  None  None
# ...          ...        ...        ...   ...   ...   ...   ...   ...   ...
# 10242  426761007       None       None  None  None  None  None  None  None
# 10243  426761007       None       None  None  None  None  None  None  None
# 10244  426761007       None       None  None  None  None  None  None  None
# 10245  426761007       None       None  None  None  None  None  None  None
# 10246  426761007       None       None  None  None  None  None  None  None
#
#           9
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 10242  None
# 10243  None
# 10244  None
# 10245  None
# 10246  None
#
# [10247 rows x 10 columns]

# %%
new_columns = ['diagnosis_{}'.format(i+1) for i in range(diag.shape[1])]
diag.columns = new_columns
edited_data = pd.concat([data, diag], axis=1)

# %%
edited_data.drop(columns=['diagnosis', 'diagnosis_3', 'diagnosis_4',
                          'diagnosis_5', 'diagnosis_6', 'diagnosis_7',
                          'diagnosis_8', 'diagnosis_9', 'diagnosis_10'
                          ], axis=1, inplace=True)

# %%
edited_data.to_csv("./edited_ecg_records.csv", index= False)

# %%
edited_data = pd.read_csv('/kaggle/working/edited_ecg_records.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 edited_data = pd.read_csv('/kaggle/working/edited_ecg_records.csv')
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\amand\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/edited_ecg_records.csv'

# %%
edited_data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 edited_data.info()
#
# NameError: name 'edited_data' is not defined

# %%
top_5_diagnosis = edited_data['diagnosis_1'].value_counts().nlargest(5)


sorted_top_5_diagnosis = top_5_diagnosis.sort_values(ascending=False)


plt.figure(figsize=(15, 12))
ax = sns.countplot(y='diagnosis_1', data=edited_data, order=sorted_top_5_diagnosis.index)
for i, count in enumerate(sorted_top_5_diagnosis):
    ax.text(count + 1, i, str(count+1))


plt.title("Chapman xioming top 5 diagnosis")

# %%
fig, ax = plt.subplots(1, 1, figsize = (16, 5))

ax.pie(
    edited_data['diagnosis_1'].value_counts().nlargest(5), 
    shadow = True, 
    explode = [.1 for i in range(0, 5)], 
    autopct = '%1.f%%',
    textprops = {'size' : 14, 'color' : 'white'}
)

# %%
fig, ax = plt.subplots(1, 1, figsize = (16, 5))

ax.pie(
    edited_data['diagnosis_2'].value_counts().nlargest(5), 
    shadow = True, 
    explode = [.1 for i in range(0, 5)], 
    autopct = '%1.f%%',
    textprops = {'size' : 14, 'color' : 'white'}
)

# %%
num_cols = edited_data.select_dtypes(include = ['int64']).columns.tolist()
for col in num_cols:
        sns.histplot(edited_data[col], kde=True)
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.title('Distribution of {}'.format(col))
        plt.show()

# %%
len(num_cols)

# %%
ig, ax = plt.subplots(6, 5, figsize = (7, 20), dpi = 300)
ax = ax.flatten()
pal = sns.color_palette('viridis')
for i, column in enumerate(num_cols):
    sns.kdeplot(edited_data[column], ax=ax[i], color=pal[0])
    
    
    ax[i].set_title(f'{column} Distribution', size = 7)
    ax[i].set_xlabel(None)
    ax[i].set_ylabel(None)
    
fig.suptitle('Distribution of Feature\n\n', fontsize = 15, fontweight = 'bold')

plt.tight_layout()

# %%
edited_data.groupby(['sex', 'diagnosis_1', 'diagnosis_2']).nunique()
